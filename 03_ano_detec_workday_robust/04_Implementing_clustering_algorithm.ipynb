# %%
# %run ClusterAlg.py

# %%
from time import clock
tic = clock()
for i in xrange(1):
    test()
toc = clock()
print('total simulation time is %f'%(toc-tic))
# m = MedianHeap([1.4, 2.1, 5.0, 5.0])
# print('median, ', m.get())
# Out:
# cluster,  [3, 3, 0, 0, 0, 1, 2, 0, 3, 0, 0, 3, 3, 1, 2]
# ...
