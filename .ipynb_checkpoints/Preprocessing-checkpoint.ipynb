# %%
data_folder = '/home/jzh/Waze/'

# %%
import csv

# %%
with open(data_folder + '/waze_jams.csv', 'rb') as csvfile:
    reader = csv.DictReader(csvfile)
    i = 0
    for row in reader:
        print(row['uuid'], row['speed'], row['street'], row['delay'], row['Length'])
        i += 1
        if i > 100:
            break
# Out:
# ('e8719565-0af4-33da-bdbe-1d87fafcc2bc', '1.26940247267598900', 'River St', '132', '185')
# ('1f24a035-717c-340c-ad54-d05b99cba1f0', '6.74255160244573700', 'Washington St', '76', '1066')
# ('67cf2f62-0168-373d-9926-dc2db73a9214', '2.62094440385186200', 'Washington St', '284', '937')
# ('cec2ad22-032c-37de-aac1-6b23f8739500', '5.38161660859767700', 'Hyde Park Ave', '72', '695')
# ('f015315d-1b92-3167-9e66-8fe6869452ed', '2.63756315452445640', 'Brighton Ave', '80', '355')
# ('9ec8bd65-211b-32e5-9dd1-c4f4c00e5f70', '6.49579070833004900', 'Beacon St', '118', '1549')
# ('89afaa58-707c-351d-aafe-7a58a91defa4', '4.84374257000774000', 'Chestnut Hill Ave', '65', '618')
# ('72766d6b-4fe3-315d-ab52-2ca525759e00', '1.16165739772588200', 'Chestnut Hill Ave', '154', '206')
# ('6de0f29a-c5fb-39c3-9646-26071fef8163', '2.38837102898857670', 'Arsenal St', '99', '313')
# ('03d4215e-f282-3259-8a99-8384ef520d84', '2.99968319990535640', 'Brookline Ave', '91', '373')
# ...

# %%
with open(data_folder + '/waze_alerts.csv', 'rb') as csvfile:
    reader = csv.DictReader(csvfile)
    i = 0
    for row in reader:
        print(row['uuid'], row['type'], row['street'], row['locx'], row['locy'])
        i += 1
        if i > 100:
            break
# Out:
# ('9a86dadd-ebf6-34c0-85db-fe13d770dad0', 'WEATHERHAZARD', 'Commonwealth Ave', '-71.084192', '42.350065')
# ('00751e34-fc43-3e2d-bb61-eb437039ba1f', 'WEATHERHAZARD', 'Cambridge St', '-71.131365', '42.356099')
# ('a90db0a0-50cd-3c2a-bf10-e0a0d19d2abb', 'WEATHERHAZARD', 'Charles St', '-71.068589', '42.354682')
# ('df31b80e-76bf-3fc4-a4a1-d919b73b11a2', 'WEATHERHAZARD', 'Commonwealth Ave', '-71.104176', '42.349821')
# ('6fec1350-48d3-35f0-87a4-fc805adf37a9', 'JAM', 'Jamaicaway', '-71.116486', '42.318471')
# ('c6a23f3a-a5f3-3740-b8ed-a2ffb93139c3', 'JAM', 'Harvard Ave', '-71.131271', '42.350854')
# ('9f8255cd-07d0-3b13-ba93-02ac520b6450', 'WEATHERHAZARD', 'Charlesgate', '-71.092333', '42.347833')
# ('0ce5ba41-1418-33c9-b6ca-2c2db1a1536d', 'WEATHERHAZARD', 'Storrow Dr E', '-71.080735', '42.353922')
# ('ea2661cd-e054-3df0-91e7-81938d15d3b7', 'JAM', 'Cambridge St', '-71.118656', '42.360714')
# ('ef43a5b2-bc3a-311c-ac45-e933098272b9', 'JAM', 'Storrow Dr E', '-71.072335', '42.360909')
# ...
