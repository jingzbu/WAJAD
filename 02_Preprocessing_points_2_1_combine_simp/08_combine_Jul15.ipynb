# %%
data_folder = '/home/jzh/Waze/'

# %%
import json

# %%
# Loading JSON data
with open(data_folder + '/uuid_list_Jul15.json', 'r') as json_file:
    uuid_list_Jul15 = json.load(json_file)

with open(data_folder + '/x_list_Jul15.json', 'r') as json_file:
    x_list_Jul15 = json.load(json_file)
    
with open(data_folder + '/y_list_Jul15.json', 'r') as json_file:
    y_list_Jul15 = json.load(json_file)

# %%
assert(len(uuid_list_Jul15) == len(x_list_Jul15))
assert(len(uuid_list_Jul15) == len(y_list_Jul15))

# %%
uuid_list_Jul15[0:30]
# Out:
# [u'89c1ab07-8223-38ac-adeb-cb15896172d7',
#  u'89c1ab07-8223-38ac-adeb-cb15896172d7',
#  u'89c1ab07-8223-38ac-adeb-cb15896172d7',
#  u'89c1ab07-8223-38ac-adeb-cb15896172d7',
#  u'89c1ab07-8223-38ac-adeb-cb15896172d7',
#  u'89c1ab07-8223-38ac-adeb-cb15896172d7',
#  u'baa5804b-020c-3eff-9c0a-6c9862601345',
#  u'baa5804b-020c-3eff-9c0a-6c9862601345',
#  u'baa5804b-020c-3eff-9c0a-6c9862601345',
#  u'baa5804b-020c-3eff-9c0a-6c9862601345',
#  u'baa5804b-020c-3eff-9c0a-6c9862601345',
#  u'baa5804b-020c-3eff-9c0a-6c9862601345',
#  u'baa5804b-020c-3eff-9c0a-6c9862601345',
#  u'baa5804b-020c-3eff-9c0a-6c9862601345',
#  u'baa5804b-020c-3eff-9c0a-6c9862601345',
#  u'9ff2a3ae-8656-3822-815a-b0613fe1b424',
#  u'9ff2a3ae-8656-3822-815a-b0613fe1b424',
#  u'9ff2a3ae-8656-3822-815a-b0613fe1b424',
#  u'9ff2a3ae-8656-3822-815a-b0613fe1b424',
#  u'9ff2a3ae-8656-3822-815a-b0613fe1b424',
#  u'9ff2a3ae-8656-3822-815a-b0613fe1b424',
#  u'842b7edb-2746-3a03-b8df-66d424cd822b',
# ...

# %%
idx_list = []  # index list for the "turning points;" note that a uuid correspond to many points

L = len(uuid_list_Jul15)  # number of points

for i in range(L-1):
    if uuid_list_Jul15[i+1] != uuid_list_Jul15[i]:
        idx_list.append(i)
#     if len(idx_list) > 2:
#         break

# %%
len(idx_list), L
# Out:
# (423221, 5270503)

# %%
import numpy as np

points_dict_Jul15 = {}

len_idx_list = len(idx_list)
for i in range(len_idx_list):
    x_y_mima_list = []
    if i == 0:
        endPts = []
        miX = min([float(x_list_Jul15[j]) for j in range(idx_list[i] + 1)])
        maX = max([float(x_list_Jul15[j]) for j in range(idx_list[i] + 1)])
        miY = min([float(y_list_Jul15[j]) for j in range(idx_list[i] + 1)])
        maY = max([float(y_list_Jul15[j]) for j in range(idx_list[i] + 1)])
        endPts.append([miX, miY])
        endPts.append([miX, maY])
        endPts.append([maX, miY])
        endPts.append([maX, maY])
        x_y_mima_list.append(endPts)
        x_y_mima_list.append(len(range(idx_list[i] + 1)))
    else:
        endPts = []
        miX = min([float(x_list_Jul15[j]) for j in range(idx_list[i-1] + 1, idx_list[i] + 1)])
        maX = max([float(x_list_Jul15[j]) for j in range(idx_list[i-1] + 1, idx_list[i] + 1)])
        miY = min([float(y_list_Jul15[j]) for j in range(idx_list[i-1] + 1, idx_list[i] + 1)])
        maY = max([float(y_list_Jul15[j]) for j in range(idx_list[i-1] + 1, idx_list[i] + 1)])
        endPts.append([miX, miY])
        endPts.append([miX, maY])
        endPts.append([maX, miY])
        endPts.append([maX, maY])
        x_y_mima_list.append(endPts)
        x_y_mima_list.append(len(range(idx_list[i-1] + 1, idx_list[i] + 1)))
    points_dict_Jul15[uuid_list_Jul15[idx_list[i]]] = x_y_mima_list
#     if i > 3:
#         break
with open(data_folder + '/points_dict_Jul15.json', 'w') as json_file:
    json.dump(points_dict_Jul15, json_file)
